# %%
data = read.table("data.csv", 
                  header = TRUE,
                  sep=",",
                  stringsAsFactors=TRUE)
head(data, n=4)
summary(data)
# Out:
#   ClaimID                              PatientID
# 1 10944daf-f7d5-4e1d-8216-72ffa609fe41 8552381d-7960-4f64-b190-b20b8ada00a1
# 2 fcbebb25-fc24-4c0f-a966-749edcf83fb1 327f43ad-e3bd-4473-a9ed-46483a0a156f
# 3 9e9983e7-9ea7-45f5-84d8-ce49ccd8a4a1 6f3acdf7-73aa-4afa-9c2e-b25b27bdb5b0
# 4 a06273ed-44bb-452b-bbad-8618de080494 5d58e183-701e-406c-a8c6-5b73cac5e912
#   ProviderID                           ClaimAmount ClaimDate  DiagnosisCode
# 1 4a4cb19c-4863-41cf-84b0-c2b21aace988 3807.95     2024-06-07 yy006
# 2 422e02dd-c1fd-43dd-8af4-0c3523f997b1 9512.07     2023-05-30 tD052
# 3 f7733b3f-0980-47b5-a7a0-ee390869355b 7346.74     2022-09-27 zx832
# 4 f7a04581-de96-44ee-b773-8adac02baa59 6026.72     2023-06-25 kr421
#   ProcedureCode PatientAge PatientGender ProviderSpecialty ClaimStatus
# 1 hd662         16         M             Cardiology        Pending
# 2 mH831         27         M             Pediatrics        Approved
# ...

# %%
new_data = data[,c(5, 4)]
new_data = na.omit(unique(new_data))

head(new_data, n=4)
# Out:
#   ClaimDate  ClaimAmount
# 1 2024-06-07 3807.95
# 2 2023-05-30 9512.07
# 3 2022-09-27 7346.74
# 4 2023-06-25 6026.72

# %%
write.csv(new_data,"new_data.csv")
