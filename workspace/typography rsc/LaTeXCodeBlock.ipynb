# %%
KeyWords = ["def", "class ç", "str", "int", "bool", "float", "'°'", '"°"', ".ç", "_", "%"]
class automata():
    def __init__(self, rsc : str):
        self.activator = dict(zip())
        self.rsc = rsc
        self.transitions = []
        
    def run(self):
        pass
